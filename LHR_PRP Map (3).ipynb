# %%
import sys
print(sys.executable)
# Out:
# /home/pyodide/this.program

# %%
# %pip install folium

# %%
import folium

hackensack_coords = [40.738893, -74.104844]


m = folium.Map(location=hackensack_coords, zoom_start=14, tiles=None)

folium.TileLayer(
    tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
    attr='ESRI World Imagery',
    name='Satellite',
    overlay=False,
    control=True
).add_to(m)

# %%
locations1 = [
    {"name": "Western Electric Site (Nokia)", "lat": 40.73149253278342, "lon": -74.11383937631429},
    {"name": "Standard Chlorine Site (Beazer,OxyChem, Cooper, Apogent)", "lat": 40.75041765205132, "lon": -74.09951944232327},
    {"name": "Federal Shipbuilding Site (US Steel, RTC Properties)", "lat": 40.724401, "lon": -74.106595},
    {"name": "Meadows Rail Yard Facility (Conrail)", "lat": 40.74429235539165, "lon": -74.09892594747733},
    {"name": "United Cork/BASF Site (BASF)", "lat": 40.72030593141203, "lon": -74.11614328795092}]

radius=10
for loc in locations1:
    folium.CircleMarker(
        location=[loc["lat"], loc["lon"]],
        radius=radius,
        color="black",
        weight=1,
        fill_opacity=0.6,
        opacity=1,
        fill_color="orange",
        fill=False,
        popup="{} pixels".format(radius),
        tooltip=loc["name"]
    ).add_to(m)

locations2 = [
    {"name": "PJP Landfill", "lat": 40.735198082066, "lon": -74.08127133027752},
    {"name": "Nicholas Galvanizing Site", "lat": 40.74331668648509, "lon": -74.07381394376795},
    {"name": "Kuehne Chemical Site", "lat": 40.734152336390444, "lon": -74.1005129186414},
    {"name": "PMC Global Site", "lat": 40.76413159448509, "lon": -74.13998306211818},
    {"name": "Trumbull Asphalt Site", "lat": 40.74438574017153, "lon": -74.0871082898045}]

for loc in locations2:
    folium.CircleMarker(
        location=[loc["lat"], loc["lon"]],
        radius=radius,
        color="black",
        weight=1,
        fill_opacity=0.6,
        opacity=1,
        fill_color="yellow",
        fill=False,
        popup="{} pixels".format(radius),
        tooltip=loc["name"]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea8dbab08add3169d6bdb39e32d75e50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea8dbab08add3169d6bdb39e32d75e50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea8dbab08add3169d6bdb39e32d75e50 = L.map(
#                 &quot;map_ea8dbab08add3169d6bdb39e32d75e50&quot;,
#                 {
#                     center: [40.738893, -74.104844],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03f4e48c3f8af25817de1df24a1a8d61 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;ESRI World Imagery&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03f4e48c3f8af25817de1df24a1a8d61.addTo(map_ea8dbab08add3169d6bdb39e32d75e50);
#
#
#             var circle_marker_0f9c7ac4915b76c40b231907140c5b38 = L.circleMarker(
#                 [40.73149253278342, -74.11383937631429],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ea8dbab08add3169d6bdb39e32d75e50);
#
#
#         var popup_b41cc841f22aeb106906ef0d248a3f41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23bf5cd91dd96a237467ccdc84aac88e = $(`&lt;div id=&quot;html_23bf5cd91dd96a237467ccdc84aac88e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10 pixels&lt;/div&gt;`)[0];
#                 popup_b41cc841f22aeb106906ef0d248a3f41.setContent(html_23bf5cd91dd96a237467ccdc84aac88e);
#
#
#
#         circle_marker_0f9c7ac4915b76c40b231907140c5b38.bindPopup(popup_b41cc841f22aeb106906ef0d248a3f41)
#         ;
#
#
#
#
#             circle_marker_0f9c7ac4915b76c40b231907140c5b38.bindTooltip(
#                 `&lt;div&gt;
#                      Western Electric Site (Nokia)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b747b2907d71145bc15c2c472ed96edd = L.circleMarker(
#                 [40.75041765205132, -74.09951944232327],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ea8dbab08add3169d6bdb39e32d75e50);
#
#
#         var popup_480b2a7d9abd649f24baf4d124eed240 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_165e7e3b95e7cf60f697e6a12694d1a6 = $(`&lt;div id=&quot;html_165e7e3b95e7cf60f697e6a12694d1a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10 pixels&lt;/div&gt;`)[0];
#                 popup_480b2a7d9abd649f24baf4d124eed240.setContent(html_165e7e3b95e7cf60f697e6a12694d1a6);
#
#
#
#         circle_marker_b747b2907d71145bc15c2c472ed96edd.bindPopup(popup_480b2a7d9abd649f24baf4d124eed240)
#         ;
#
#
#
#
#             circle_marker_b747b2907d71145bc15c2c472ed96edd.bindTooltip(
#                 `&lt;div&gt;
#                      Standard Chlorine Site (Beazer,OxyChem, Cooper, Apogent)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_02ed153a8abbf03f7aa67fafa0ee00e6 = L.circleMarker(
#                 [40.724401, -74.106595],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ea8dbab08add3169d6bdb39e32d75e50);
#
#
#         var popup_c00b40dbfbf44a5e848ada5c970b2e70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69209c752183de400351500504a696bf = $(`&lt;div id=&quot;html_69209c752183de400351500504a696bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10 pixels&lt;/div&gt;`)[0];
#                 popup_c00b40dbfbf44a5e848ada5c970b2e70.s

# %%
m.save("hackensack_map.html")
